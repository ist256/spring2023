# %% [markdown]
# # End-To-End Example: Today's Weather
#
# This example will input a location and then output today's current weather conditions at that location.
#
# To complete this example we will use the following API's
#
# - https://www.openstreetmap.org/ Geocode api to get GPS coordinates for a location eg. Syracuse, NY
# - https://openweathermap.org/ forecast api to get the currnt weather conditions for those GPS coordinates

# %%
# Todo list
# input a location eg. Syracuse, ny
# use the google geocode api to get a lat/lng
# use the darksky api and lat/lng to get current weather conditions
# output current weather conditions (temperature and summary (rain, snow, etc...))

# %%
import requests

# %%
def geocode(location):
    query_string = {'q' : location, 'format': 'json'}
    url='https://nominatim.openstreetmap.org/search' 
    response = requests.get(url, params = query_string)
    response.raise_for_status()
    geodata = response.json()
    return geodata
        
# Testing with syracuse, NY 
geocode('Syracuse, NY')
# Out:
# [{'place_id': 298364595,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 174916,
#   'boundingbox': ['42.984165', '43.086121', '-76.204629', '-76.074273'],
#   'lat': '43.0481221',
#   'lon': '-76.1474244',
#   'display_name': 'City of Syracuse, Salina, Onondaga County, New York, United States',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.6767762857760726,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'},
#  {'place_id': 67220594,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'node',
#   'osm_id': 6241108067,
#   'boundingbox': ['43.0718312', '43.0818312', '-76.1744003', '-76.1644003'],
#   'lat': '43.0768312',
#   'lon': '-76.1694003',
#   'display_name': 'Syracuse, 131, NBT Bank Parkway, City of Syracuse, Salina, Onondaga County, New York, 13208, United States',
#   'class': 'railway',
#   'type': 'station',
#   'importance': 0.4272524353626238,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/transport_train_station2.p.20.png'},
#  {'place_id': 36528029,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'node',
#   'osm_id': 2997656284,
#   'boundingbox': ['43.0770382', '43.0771382', '-76.1700021', '-76.1699021'],
#   'lat': '43.0770882',
#   'lon': '-76.1699521',
#   'display_name': 'Syracuse, Walsh Circle, City of Syracuse, Salina, Onondaga County, New York, 13290, United States',
#   'class': 'railway',
#   'type': 'stop',
#   'importance': 0.11010000000000002}]

# %%
def getweather(lat,lon):
    key = '67f9d45c32dd086df27f2b7a90370a8e' # sign up for your own key at https://openweathermap.org/ 
    query_string = { 'lat' : lat, 'lon': lon, 'appid' : key, 'units' : 'imperial'}
    url='https://api.openweathermap.org/data/2.5/onecall' 
    response = requests.get(url, params=query_string)
    response.raise_for_status()
    #print (response.url)
    weather = response.json()
    return weather

# Testing with syracuse, NY coordinates
getweather( 43.0481221, -76.1474244 )
# Out:
# {'lat': 43.0481,
#  'lon': -76.1474,
#  'timezone': 'America/New_York',
#  'timezone_offset': -14400,
#  'current': {'dt': 1667250018,
#   'sunrise': 1667216269,
#   'sunset': 1667253506,
#   'temp': 62.17,
#   'feels_like': 61.14,
#   'pressure': 1011,
#   'humidity': 65,
#   'dew_point': 50.27,
#   'uvi': 0.2,
#   'clouds': 100,
#   'visibility': 10000,
#   'wind_speed': 8.32,
#   'wind_deg': 183,
#   'wind_gust': 17.45,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}]},
#  'minutely': [{'dt': 1667250060, 'precipitation': 0},
#   {'dt': 1667250120, 'precipitation': 0},
#   {'dt': 1667250180, 'precipitation': 0},
#   {'dt': 1667250240, 'precipitation': 0},
#   {'dt': 1667250300, 'precipitation': 0},
#   {'dt': 1667250360, 'precipitation': 0},
#   {'dt': 1667250420, 'precipitation': 0},
#   {'dt': 1667250480, 'precipitation': 0},
#   {'dt': 1667250540, 'precipitation': 0},
#   {'dt': 1667250600, 'precipitation': 0},
#   {'dt': 1667250660, 'precipitation': 0},
#   {'dt': 1667250720, 'precipitation': 0},
#   {'dt': 1667250780, 'precipitation': 0},
#   {'dt': 1667250840, 'precipitation': 0},
#   {'dt': 1667250900, 'precipitation': 0},
#   {'dt': 1667250960, 'precipitation': 0},
#   {'dt': 1667251020, 'precipitation': 0},
#   {'dt': 1667251080, 'precipitation': 0},
#   {'dt': 1667251140, 'precipitation': 0},
#   {'dt': 1667251200, 'precipitation': 0},
#   {'dt': 1667251260, 'precipitation': 0},
#   {'dt': 1667251320, 'precipitation': 0},
#   {'dt': 1667251380, 'precipitation': 0},
#   {'dt': 1667251440, 'precipitation': 0},
#   {'dt': 1667251500, 'precipitation': 0},
#   {'dt': 1667251560, 'precipitation': 0},
#   {'dt': 1667251620, 'precipitation': 0},
#   {'dt': 1667251680, 'precipitation': 0},
#   {'dt': 1667251740, 'precipitation': 0},
#   {'dt': 1667251800, 'precipitation': 0},
#   {'dt': 1667251860, 'precipitation': 0},
#   {'dt': 1667251920, 'precipitation': 0},
#   {'dt': 1667251980, 'precipitation': 0},
#   {'dt': 1667252040, 'precipitation': 0},
#   {'dt': 1667252100, 'precipitation': 0},
#   {'dt': 1667252160, 'precipitation': 0},
#   {'dt': 1667252220, 'precipitation': 0},
#   {'dt': 1667252280, 'precipitation': 0},
#   {'dt': 1667252340, 'precipitation': 0},
#   {'dt': 1667252400, 'precipitation': 0},
#   {'dt': 1667252460, 'precipitation': 0},
#   {'dt': 1667252520, 'precipitation': 0},
#   {'dt': 1667252580, 'precipitation': 0},
#   {'dt': 1667252640, 'precipitation': 0},
#   {'dt': 1667252700, 'precipitation': 0},
#   {'dt': 1667252760, 'precipitation': 0},
#   {'dt': 1667252820, 'precipitation': 0},
#   {'dt': 1667252880, 'precipitation': 0},
#   {'dt': 1667252940, 'precipitation': 0},
#   {'dt': 1667253000, 'precipitation': 0},
#   {'dt': 1667253060, 'precipitation': 0},
#   {'dt': 1667253120, 'precipitation': 0},
#   {'dt': 1667253180, 'precipitation': 0},
#   {'dt': 1667253240, 'precipitation': 0},
#   {'dt': 1667253300, 'precipitation': 0},
#   {'dt': 1667253360, 'precipitation': 0},
#   {'dt': 1667253420, 'precipitation': 0},
#   {'dt': 1667253480, 'precipitation': 0},
#   {'dt': 1667253540, 'precipitation': 0},
#   {'dt': 1667253600, 'precipitation': 0},
#   {'dt': 1667253660, 'precipitation': 0}],
#  'hourly': [{'dt': 1667250000,
#    'temp': 62.17,
#    'feels_like': 61.14,
#    'pressure': 1011,
#    'humidity': 65,
#    'dew_point': 50.27,
#    'uvi': 0.2,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 8.32,
#    'wind_deg': 183,
#    'wind_gust': 17.45,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.1},
#   {'dt': 1667253600,
#    'temp': 61.36,
#    'feels_like': 60.39,
#    'pressure': 1011,
#    'humidity': 68,
#    'dew_point': 50.72,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 8.46,
#    'wind_deg': 189,
#    'wind_gust': 20.85,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.07},
#   {'dt': 1667257200,
#    'temp': 60.15,
#    'feels_like': 59.2,
#    'pressure': 1012,
#    'humidity': 71,
#    'dew_point': 50.74,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 8.43,
#    'wind_deg': 185,
#    'wind_gust': 21.3,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.02},
#   {'dt': 1667260800,
#    'temp': 58.78,
#    'feels_like': 57.88,
#    'pressure': 1012,
#    'humidity': 75,
#    'dew_point': 50.88,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 7.02,
#    'wind_deg': 187,
#    'wind_gust': 20.18,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.1},
#   {'dt': 1667264400,
#    'temp': 57.87,
#    'feels_like': 57.02,
#    'pressure': 1013,
#    'humidity': 78,
#    'dew_point': 51.06,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 7,
#    'wind_deg': 192,
#    'wind_gust': 21.54,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.14},
#   {'dt': 1667268000,
#    'temp': 57.58,
#    'feels_like': 56.8,
#    'pressure': 1014,
#    'humidity': 80,
#    'dew_point': 50.52,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 8.03,
#    'wind_deg': 195,
#    'wind_gust': 22.7,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.13},
#   {'dt': 1667271600,
#    'temp': 57.27,
#    'feels_like': 56.55,
#    'pressure': 1014,
#    'humidity': 82,
#    'dew_point': 50.99,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 7.47,
#    'wind_deg': 204,
#    'wind_gust': 22.44,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 0.3,
#    'rain': {'1h': 0.11}},
#   {'dt': 1667275200,
#    'temp': 57.2,
#    'feels_like': 56.52,
#    'pressure': 1014,
#    'humidity': 83,
#    'dew_point': 51.37,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 6.15,
#    'wind_deg': 207,
#    'wind_gust': 18.86,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.08},
#   {'dt': 1667278800,
#    'temp': 57.34,
#    'feels_like': 56.68,
#    'pressure': 1014,
#    'humidity': 83,
#    'dew_point': 51.51,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 5.06,
#    'wind_deg': 197,
#    'wind_gust': 12.95,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1667282400,
#    'temp': 56.84,
#    'feels_like': 56.23,
#    'pressure': 1014,
#    'humidity': 85,
#    'dew_point': 51.39,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 4.72,
#    'wind_deg': 180,
#    'wind_gust': 7.7,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1667286000,
#    'temp': 56.21,
#    'feels_like': 55.58,
#    'pressure': 1014,
#    'humidity': 86,
#    'dew_point': 51.17,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 4.74,
#    'wind_deg': 180,
#    'wind_gust': 6.55,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1667289600,
#    'temp': 56.97,
#    'feels_like': 56.32,
#    'pressure': 1014,
#    'humidity': 84,
#    'dew_point': 51.31,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 4.56,
#    'wind_deg': 179,
#    'wind_gust': 9.1,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1667293200,
#    'temp': 57.06,
#    'feels_like': 56.41,
#    'pressure': 1014,
#    'humidity': 84,
#    'dew_point': 51.44,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 4.21,
#    'wind_deg': 178,
#    'wind_gust': 6.82,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1667296800,
#    'temp': 56.73,
#    'feels_like': 56.1,
#    'pressure': 1015,
#    'humidity': 85,
#    'dew_point': 51.46,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 3.62,
#    'wind_deg': 186,
#    'wind_gust': 5.01,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1667300400,
#    'temp': 54.88,
#    'feels_like': 54.3,
#    'pressure': 1015,
#    'humidity': 90,
#    'dew_point': 51.01,
#    'uvi': 0,
#    'clouds': 96,
#    'visibility': 10000,
#    'wind_speed': 4.16,
#    'wind_deg': 192,
#    'wind_gust': 4.61,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.02},
#   {'dt': 1667304000,
#    'temp': 55.18,
#    'feels_like': 54.59,
#    'pressure': 1015,
#    'humidity': 89,
#    'dew_point': 51.17,
#    'uvi': 0,
#    'clouds': 94,
#    'visibility': 10000,
#    'wind_speed': 4.16,
#    'wind_deg': 195,
#    'wind_gust': 5.32,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.05},
#   {'dt': 1667307600,
#    'temp': 57.02,
#    'feels_like': 56.55,
#    'pressure': 1015,
#    'humidity': 88,
#    'dew_point': 52.52,
#    'uvi': 0.18,
#    'clouds': 98,
#    'visibility': 10000,
#    'wind_speed': 3.91,
#    'wind_deg': 189,
#    'wind_gust': 6.71,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.47,
#    'rain': {'1h': 0.27}},
#   {'dt': 1667311200,
#    'temp': 59.67,
#    'feels_like': 59.14,
#    'pressure': 1016,
#    'humidity': 81,
#    'dew_point': 53.13,
#    'uvi': 0.6,
#    'clouds': 95,
#    'visibility': 10000,
#    'wind_speed': 4.32,
#    'wind_deg': 207,
#    'wind_gust': 7.7,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.4,
#    'rain': {'1h': 0.17}},
#   {'dt': 1667314800,
#    'temp': 62.01,
#    'feels_like': 61.52,
#    'pressure': 1016,
#    'humidity': 77,
#    'dew_point': 53.92,
#    'uvi': 1.2,
#    'clouds': 97,
#    'visibility': 10000,
#    'wind_speed': 5.64,
#    'wind_deg': 251,
#    'wind_gust': 9.37,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.6,
#    'rain': {'1h': 0.24}},
#   {'dt': 1667318400,
#    'temp': 62.2,
#    'feels_like': 61.79,
#    'pressure': 1016,
#    'humidity': 78,
#    'dew_point': 54.43,
#    'uvi': 1.3,
#    'clouds': 97,
#    'visibility': 10000,
#    'wind_speed': 7.49,
#    'wind_deg': 267,
#    'wind_gust': 10.71,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.53,
#    'rain': {'1h': 0.11}},
#   {'dt': 1667322000,
#    'temp': 61.59,
#    'feels_like': 61.21,
#    'pressure': 1016,
#    'humidity': 80,
#    'dew_point': 54.52,
#    'uvi': 1.48,
#    'clouds': 97,
#    'visibility': 10000,
#    'wind_speed': 6.35,
#    'wind_deg': 269,
#    'wind_gust': 9.86,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.53},
#   {'dt': 1667325600,
#    'temp': 64.06,
#    'feels_like': 63.64,
#    'pressure': 1016,
#    'humidity': 74,
#    'dew_point': 54.9,
#    'uvi': 1.35,
#    'clouds': 94,
#    'visibility': 10000,
#    'wind_speed': 6.89,
#    'wind_deg': 280,
#    'wind_gust': 10.04,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.49,
#    'rain': {'1h': 0.11}},
#   {'dt': 1667329200,
#    'temp': 63.66,
#    'feels_like': 63.36,
#    'pressure': 1016,
#    'humidity': 77,
#    'dew_point': 55.4,
#    'uvi': 1.15,
#    'clouds': 76,
#    'visibility': 10000,
#    'wind_speed': 9.04,
#    'wind_deg': 287,
#    'wind_gust': 12.88,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.56,
#    'rain': {'1h': 0.61}},
#   {'dt': 1667332800,
#    'temp': 61.41,
#    'feels_like': 61.25,
#    'pressure': 1016,
#    'humidity': 85,
#    'dew_point': 56.03,
#    'uvi': 0.62,
#    'clouds': 87,
#    'visibility': 10000,
#    'wind_speed': 7.47,
#    'wind_deg': 286,
#    'wind_gust': 14.07,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.57,
#    'rain': {'1h': 0.44}},
#   {'dt': 1667336400,
#    'temp': 61.12,
#    'feels_like': 60.98,
#    'pressure': 1016,
#    'humidity': 86,
#    'dew_point': 56.08,
#    'uvi': 0.21,
#    'clouds': 83,
#    'visibility': 10000,
#    'wind_speed': 7.14,
#    'wind_deg': 291,
#    'wind_gust': 15.08,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.58,
#    'rain': {'1h': 0.23}},
#   {'dt': 1667340000,
#    'temp': 59.23,
#    'feels_like': 59.13,
#    'pressure': 1017,
#    'humidity': 91,
#    'dew_point': 55.8,
#    'uvi': 0,
#    'clouds': 86,
#    'visibility': 10000,
#    'wind_speed': 6.76,
#    'wind_deg': 296,
#    'wind_gust': 16.42,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 0.5,
#    'rain': {'1h': 0.15}},
#   {'dt': 1667343600,
#    'temp': 58.3,
#    'feels_like': 58.24,
#    'pressure': 1018,
#    'humidity': 94,
#    'dew_point': 55.58,
#    'uvi': 0,
#    'clouds': 89,
#    'visibility': 10000,
#    'wind_speed': 7.2,
#    'wind_deg': 295,
#    'wind_gust': 19.39,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.5},
#   {'dt': 1667347200,
#    'temp': 57.16,
#    'feels_like': 57,
#    'pressure': 1020,
#    'humidity': 94,
#    'dew_point': 54.5,
#    'uvi': 0,
#    'clouds': 90,
#    'visibility': 10000,
#    'wind_speed': 7.96,
#    'wind_deg': 293,
#    'wind_gust': 21.07,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.39},
#   {'dt': 1667350800,
#    'temp': 55,
#    'feels_like': 54.72,
#    'pressure': 1020,
#    'humidity': 96,
#    'dew_point': 52.92,
#    'uvi': 0,
#    'clouds': 35,
#    'visibility': 10000,
#    'wind_speed': 6.26,
#    'wind_deg': 283,
#    'wind_gust': 19.71,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1667354400,
#    'temp': 53.74,
#    'feels_like': 53.33,
#    'pressure': 1021,
#    'humidity': 96,
#    'dew_point': 51.85,
#    'uvi': 0,
#    'clouds': 30,
#    'visibility': 10000,
#    'wind_speed': 5.26,
#    'wind_deg': 268,
#    'wind_gust': 15.7,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1667358000,
#    'temp': 52.92,
#    'feels_like': 52.47,
#    'pressure': 1021,
#    'humidity': 97,
#    'dew_point': 51.19,
#    'uvi': 0,
#    'clouds': 25,
#    'visibility': 10000,
#    'wind_speed': 4.99,
#    'wind_deg': 254,
#    'wind_gust': 11.12,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1667361600,
#    'temp': 52.61,
#    'feels_like': 52.12,
#    'pressure': 1022,
#    'humidity': 97,
#    'dew_point': 51.04,
#    'uvi': 0,
#    'clouds': 25,
#    'visibility': 10000,
#    'wind_speed': 5.19,
#    'wind_deg': 260,
#    'wind_gust': 12.73,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1667365200,
#    'temp': 52.34,
#    'feels_like': 51.87,
#    'pressure': 1022,
#    'humidity': 98,
#    'dew_point': 50.77,
#    'uvi': 0,
#    'clouds': 28,
#    'visibility': 10000,
#    'wind_speed': 5.5,
#    'wind_deg': 259,
#    'wind_gust': 14.03,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1667368800,
#    'temp': 52.07,
#    'feels_like': 51.53,
#    'pressure': 1023,
#    'humidity': 97,
#    'dew_point': 50.29,
#    'uvi': 0,
#    'clouds': 31,
#    'visibility': 10000,
#    'wind_speed': 5.1,
#    'wind_deg': 259,
#    'wind_gust': 11.97,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1667372400,
#    'temp': 50.86,
#    'feels_like': 50.16,
#    'pressure': 1023,
#    'humidity': 96,
#    'dew_point': 48.99,
#    'uvi': 0,
#    'clouds': 37,
#    'visibility': 10000,
#    'wind_speed': 4.5,
#    'wind_deg': 260,
#    'wind_gust': 9.22,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1667376000,
#    'temp': 49.62,
#    'feels_like': 48.2,
#    'pressure': 1024,
#    'humidity': 96,
#    'dew_point': 47.57,
#    'uvi': 0,
#    'clouds': 27,
#    'visibility': 10000,
#    'wind_speed': 4.34,
#    'wind_deg': 261,
#    'wind_gust': 8.08,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'pop': 0},
#   {'dt': 1667379600,
#    'temp': 48.54,
#    'feels_like': 47.01,
#    'pressure': 1024,
#    'humidity': 95,
#    'dew_point': 46.35,
#    'uvi': 0,
#    'clouds': 21,
#    'visibility': 10000,
#    'wind_speed': 4.25,
#    'wind_deg': 256,
#    'wind_gust': 6.33,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'pop': 0},
#   {'dt': 1667383200,
#    'temp': 47.79,
#    'feels_like': 46.13,
#    'pressure': 1025,
#    'humidity': 95,
#    'dew_point': 45.46,
#    'uvi': 0,
#    'clouds': 18,
#    'visibility': 10000,
#    'wind_speed': 4.25,
#    'wind_deg': 256,
#    'wind_gust': 6.22,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'pop': 0},
#   {'dt': 1667386800,
#    'temp': 47.05,
#    'feels_like': 45.32,
#    'pressure': 1025,
#    'humidity': 94,
#    'dew_point': 44.65,
#    'uvi': 0,
#    'clouds': 16,
#    'visibility': 10000,
#    'wind_speed': 4.18,
#    'wind_deg': 254,
#    'wind_gust': 5.91,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'pop': 0},
#   {'dt': 1667390400,
#    'temp': 46.63,
#    'feels_like': 45.37,
#    'pressure': 1027,
#    'humidity': 94,
#    'dew_point': 44.11,
#    'uvi': 0,
#    'clouds': 15,
#    'visibility': 10000,
#    'wind_speed': 3.53,
#    'wind_deg': 258,
#    'wind_gust': 5.08,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'pop': 0},
#   {'dt': 1667394000,
#    'temp': 49.44,
#    'feels_like': 48.9,
#    'pressure': 1027,
#    'humidity': 88,
#    'dew_point': 45.36,
#    'uvi': 0.21,
#    'clouds': 6,
#    'visibility': 10000,
#    'wind_speed': 3.15,
#    'wind_deg': 259,
#    'wind_gust': 6.22,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1667397600,
#    'temp': 52.75,
#    'feels_like': 51.49,
#    'pressure': 1028,
#    'humidity': 80,
#    'dew_point': 46.09,
#    'uvi': 0.73,
#    'clouds': 7,
#    'visibility': 10000,
#    'wind_speed': 3.62,
#    'wind_deg': 283,
#    'wind_gust': 5.79,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'pop': 0},
#   {'dt': 1667401200,
#    'temp': 55.63,
#    'feels_like': 54.32,
#    'pressure': 1028,
#    'humidity': 73,
#    'dew_point': 46.27,
#    'uvi': 1.47,
#    'clouds': 12,
#    'visibility': 10000,
#    'wind_speed': 4,
#    'wind_deg': 299,
#    'wind_gust': 5.32,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'pop': 0},
#   {'dt': 1667404800,
#    'temp': 58.12,
#    'feels_like': 56.79,
#    'pressure': 1028,
#    'humidity': 67,
#    'dew_point': 46.42,
#    'uvi': 2.09,
#    'clouds': 22,
#    'visibility': 10000,
#    'wind_speed': 4.63,
#    'wind_deg': 319,
#    'wind_gust': 5.93,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'pop': 0},
#   {'dt': 1667408400,
#    'temp': 59.97,
#    'feels_like': 58.59,
#    'pressure': 1027,
#    'humidity': 62,
#    'dew_point': 46.13,
#    'uvi': 2.39,
#    'clouds': 31,
#    'visibility': 10000,
#    'wind_speed': 4.83,
#    'wind_deg': 338,
#    'wind_gust': 6.49,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1667412000,
#    'temp': 61.23,
#    'feels_like': 59.77,
#    'pressure': 1026,
#    'humidity': 58,
#    'dew_point': 45.43,
#    'uvi': 2.18,
#    'clouds': 35,
#    'visibility': 10000,
#    'wind_speed': 4.41,
#    'wind_deg': 346,
#    'wind_gust': 5.75,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1667415600,
#    'temp': 61.45,
#    'feels_like': 59.92,
#    'pressure': 1026,
#    'humidity': 56,
#    'dew_point': 44.82,
#    'uvi': 1.59,
#    'clouds': 93,
#    'visibility': 10000,
#    'wind_speed': 4.38,
#    'wind_deg': 351,
#    'wind_gust': 5.39,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0},
#   {'dt': 1667419200,
#    'temp': 61.3,
#    'feels_like': 59.77,
#    'pressure': 1026,
#    'humidity': 56,
#    'dew_point': 44.51,
#    'uvi': 0.85,
#    'clouds': 57,
#    'visibility': 10000,
#    'wind_speed': 4.38,
#    'wind_deg': 352,
#    'wind_gust': 5.14,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'pop': 0}],
#  'daily': [{'dt': 1667232000,
#    'sunrise': 1667216269,
#    'sunset': 1667253506,
#    'moonrise': 1667240880,
#    'moonset': 1667273340,
#    'moon_phase': 0.23,
#    'temp': {'day': 60.37,
#     'min': 44.96,
#     'max': 63.43,
#     'night': 57.27,
#     'eve': 61.36,
#     'morn': 45.64},
#    'feels_like': {'day': 58.84, 'night': 56.55, 'eve': 60.39, 'morn': 42.71},
#    'pressure': 1014,
#    'humidity': 58,
#    'dew_point': 44.87,
#    'wind_speed': 9.22,
#    'wind_deg': 200,
#    'wind_gust': 23.71,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': 98,
#    'pop': 0.3,
#    'rain': 0.11,
#    'uvi': 1.35},
#   {'dt': 1667318400,
#    'sunrise': 1667302746,
#    'sunset': 1667339827,
#    'moonrise': 1667329620,
#    'moonset': 0,
#    'moon_phase': 0.25,
#    'temp': {'day': 62.2,
#     'min': 52.92,
#     'max': 64.06,
#     'night': 52.92,
#     'eve': 59.23,
#     'morn': 56.73},
#    'feels_like': {'day': 61.79, 'night': 52.47, 'eve': 59.13, 'morn': 56.1},
#    'pressure': 1016,
#    'humidity': 78,
#    'dew_point': 54.43,
#    'wind_speed': 9.04,
#    'wind_deg': 287,
#    'wind_gust': 21.07,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': 97,
#    'pop': 0.6,
#    'rain': 2.33,
#    'uvi': 1.48},
#   {'dt': 1667404800,
#    'sunrise': 1667389224,
#    'sunset': 1667426149,
#    'moonrise': 1667417820,
#    'moonset': 1667364360,
#    'moon_phase': 0.3,
#    'temp': {'day': 58.12,
#     'min': 46.63,
#     'max': 61.45,
#     'night': 49.03,
#     'eve': 53.74,
#     'morn': 47.79},
#    'feels_like': {'day': 56.79, 'night': 48.36, 'eve': 52.25, 'morn': 46.13},
#    'pressure': 1028,
#    'humidity': 67,
#    'dew_point': 46.42,
#    'wind_speed': 5.5,
#    'wind_deg': 259,
#    'wind_gust': 14.03,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': 22,
#    'pop': 0,
#    'uvi': 2.39},
#   {'dt': 1667491200,
#    'sunrise': 1667475701,
#    'sunset': 1667512472,
#    'moonrise': 1667505720,
#    'moonset': 1667455320,
#    'moon_phase': 0.34,
#    'temp': {'day': 59.36,
#     'min': 46.2,
#     'max': 64.78,
#     'night': 54.72,
#     'eve': 61.61,
#     'morn': 46.51},
#    'feels_like': {'day': 57.78, 'night': 53.28, 'eve': 60.3, 'morn': 44.51},
#    'pressure': 1028,
#    'humidity': 59,
#    'dew_point': 44.31,
#    'wind_speed': 8.77,
#    'wind_deg': 191,
#    'wind_gust': 23.82,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': 8,
#    'pop': 0,
#    'uvi': 2.27},
#   {'dt': 1667577600,
#    'sunrise': 1667562179,
#    'sunset': 1667598797,
#    'moonrise': 1667593440,
#    'moonset': 1667546100,
#    'moon_phase': 0.37,
#    'temp': {'day': 60.64,
#     'min': 49.95,
#     'max': 66.06,
#     'night': 57.7,
#     'eve': 63.18,
#     'morn': 51.64},
#    'feels_like': {'day': 59.13, 'night': 56.17, 'eve': 62.01, 'morn': 50.4},
#    'pressure': 1025,
#    'humidity': 58,
#    'dew_point': 44.91,
#    'wind_speed': 11.34,
#    'wind_deg': 192,
#    'wind_gust': 28.68,
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': 71,
#    'pop': 0,
#    'uvi': 2.13},
#   {'dt': 1667664000,
#    'sunrise': 1667648656,
#    'sunset': 1667685124,
#    'moonrise': 1667681100,
#    'moonset': 1667636760,
#    'moon_phase': 0.41,
#    'temp': {'day': 66.29,
#     'min': 53.85,
#     'max': 72.19,
#     'night': 64.4,
#     'eve': 70.11,
#     'morn': 54.86},
#    'feels_like': {'day': 65.59, 'night': 64.53, 'eve': 69.82, 'morn': 53.8},
#    'pressure': 1024,
#    'humidity': 63,
#    'dew_point': 52.45,
#    'wind_speed': 12.3,
#    'wind_deg': 190,
#    'wind_gust': 32.01,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': 34,
#    'pop': 0,
#    'uvi': 3},
#   {'dt': 1667750400,
#    'sunrise': 1667735134,
#    'sunset': 1667771452,
#    'moonrise': 1667768820,
#    'moonset': 1667723760,
#    'moon_phase': 0.44,
#    'temp': {'day': 68.68,
#     'min': 61.32,
#     'max': 73.11,
#     'night': 67.12,
#     'eve': 70.66,
#     'morn': 61.83},
#    'feels_like': {'day': 68.4, 'night': 67.19, 'eve': 70.34, 'morn': 61.61},
#    'pressure': 1020,
#    'humidity': 67,
#    'dew_point': 56.57,
#    'wind_speed': 21.97,
#    'wind_deg': 179,
#    'wind_gust': 44.13,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': 46,
#    'pop': 0.74,
#    'rain': 1.63,
#    'uvi': 3},
#   {'dt': 1667836800,
#    'sunrise': 1667821612,
#    'sunset': 1667857782,
#    'moonrise': 1667856540,
#    'moonset': 1667817960,
#    'moon_phase': 0.48,
#    'temp': {'day': 65.07,
#     'min': 53.82,
#     'max': 69.26,
#     'night': 53.82,
#     'eve': 65.14,
#     'morn': 60.04},
#    'feels_like': {'day': 63.95, 'night': 52.52, 'eve': 63.99, 'morn': 59.88},
#    'pressure': 1025,
#    'humidity': 57,
#    'dew_point': 48.61,
#    'wind_speed': 9.95,
#    'wind_deg': 262,
#    'wind_gust': 26.26,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': 30,
#    'pop': 0.7,
#    'rain': 0.37,
#    'uvi': 3}]}

# %%
# then test them here to figue out how to extract from the dictionary
geodata = geocode('Syracuse, NY')
lat = geodata[0]['lat']
lon = geodata[0]['lon']
weather = getweather(lat, lon)
weather.keys()
# Out:
# dict_keys(['lat', 'lon', 'timezone', 'timezone_offset', 'current', 'minutely', 'hourly', 'daily'])

# %%
weather['daily']
# Out:
# [{'dt': 1667232000,
#   'sunrise': 1667216269,
#   'sunset': 1667253506,
#   'moonrise': 1667240880,
#   'moonset': 1667273340,
#   'moon_phase': 0.23,
#   'temp': {'day': 61.72,
#    'min': 44.96,
#    'max': 63.73,
#    'night': 57.27,
#    'eve': 60.35,
#    'morn': 45.64},
#   'feels_like': {'day': 60.31, 'night': 56.55, 'eve': 59.41, 'morn': 42.71},
#   'pressure': 1013,
#   'humidity': 58,
#   'dew_point': 46.81,
#   'wind_speed': 9.22,
#   'wind_deg': 200,
#   'wind_gust': 23.71,
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': 99,
#   'pop': 0.3,
#   'rain': 0.27,
#   'uvi': 1.35},
#  {'dt': 1667318400,
#   'sunrise': 1667302746,
#   'sunset': 1667339827,
#   'moonrise': 1667329620,
#   'moonset': 0,
#   'moon_phase': 0.25,
#   'temp': {'day': 62.2,
#    'min': 52.92,
#    'max': 64.06,
#    'night': 52.92,
#    'eve': 59.23,
#    'morn': 56.73},
#   'feels_like': {'day': 61.79, 'night': 52.47, 'eve': 59.13, 'morn': 56.1},
#   'pressure': 1016,
#   'humidity': 78,
#   'dew_point': 54.43,
#   'wind_speed': 9.04,
#   'wind_deg': 287,
#   'wind_gust': 21.07,
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': 97,
#   'pop': 0.6,
#   'rain': 2.33,
#   'uvi': 1.48},
#  {'dt': 1667404800,
#   'sunrise': 1667389224,
#   'sunset': 1667426149,
#   'moonrise': 1667417820,
#   'moonset': 1667364360,
#   'moon_phase': 0.3,
#   'temp': {'day': 58.12,
#    'min': 46.63,
#    'max': 61.45,
#    'night': 49.03,
#    'eve': 53.74,
#    'morn': 47.79},
#   'feels_like': {'day': 56.79, 'night': 48.36, 'eve': 52.25, 'morn': 46.13},
#   'pressure': 1028,
#   'humidity': 67,
#   'dew_point': 46.42,
#   'wind_speed': 5.5,
#   'wind_deg': 259,
#   'wind_gust': 14.03,
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'clouds': 22,
#   'pop': 0,
#   'uvi': 2.39},
#  {'dt': 1667491200,
#   'sunrise': 1667475701,
#   'sunset': 1667512472,
#   'moonrise': 1667505720,
#   'moonset': 1667455320,
#   'moon_phase': 0.34,
#   'temp': {'day': 59.36,
#    'min': 46.2,
#    'max': 64.78,
#    'night': 54.72,
#    'eve': 61.61,
#    'morn': 46.51},
#   'feels_like': {'day': 57.78, 'night': 53.28, 'eve': 60.3, 'morn': 44.51},
#   'pressure': 1028,
#   'humidity': 59,
#   'dew_point': 44.31,
#   'wind_speed': 8.77,
#   'wind_deg': 191,
#   'wind_gust': 23.82,
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': 8,
#   'pop': 0,
#   'uvi': 2.27},
#  {'dt': 1667577600,
#   'sunrise': 1667562179,
#   'sunset': 1667598797,
#   'moonrise': 1667593440,
#   'moonset': 1667546100,
#   'moon_phase': 0.37,
#   'temp': {'day': 60.64,
#    'min': 49.95,
#    'max': 66.06,
#    'night': 57.7,
#    'eve': 63.18,
#    'morn': 51.64},
#   'feels_like': {'day': 59.13, 'night': 56.17, 'eve': 62.01, 'morn': 50.4},
#   'pressure': 1025,
#   'humidity': 58,
#   'dew_point': 44.91,
#   'wind_speed': 11.34,
#   'wind_deg': 192,
#   'wind_gust': 28.68,
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': 71,
#   'pop': 0,
#   'uvi': 2.13},
#  {'dt': 1667664000,
#   'sunrise': 1667648656,
#   'sunset': 1667685124,
#   'moonrise': 1667681100,
#   'moonset': 1667636760,
#   'moon_phase': 0.41,
#   'temp': {'day': 66.29,
#    'min': 53.85,
#    'max': 72.19,
#    'night': 64.4,
#    'eve': 70.11,
#    'morn': 54.86},
#   'feels_like': {'day': 65.59, 'night': 64.53, 'eve': 69.82, 'morn': 53.8},
#   'pressure': 1024,
#   'humidity': 63,
#   'dew_point': 52.45,
#   'wind_speed': 12.3,
#   'wind_deg': 190,
#   'wind_gust': 32.01,
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': 34,
#   'pop': 0,
#   'uvi': 3},
#  {'dt': 1667750400,
#   'sunrise': 1667735134,
#   'sunset': 1667771452,
#   'moonrise': 1667768820,
#   'moonset': 1667723760,
#   'moon_phase': 0.44,
#   'temp': {'day': 68.68,
#    'min': 61.32,
#    'max': 73.11,
#    'night': 67.12,
#    'eve': 70.66,
#    'morn': 61.83},
#   'feels_like': {'day': 68.4, 'night': 67.19, 'eve': 70.34, 'morn': 61.61},
#   'pressure': 1020,
#   'humidity': 67,
#   'dew_point': 56.57,
#   'wind_speed': 21.97,
#   'wind_deg': 179,
#   'wind_gust': 44.13,
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': 46,
#   'pop': 0.74,
#   'rain': 1.63,
#   'uvi': 3},
#  {'dt': 1667836800,
#   'sunrise': 1667821612,
#   'sunset': 1667857782,
#   'moonrise': 1667856540,
#   'moonset': 1667817960,
#   'moon_phase': 0.48,
#   'temp': {'day': 65.07,
#    'min': 53.82,
#    'max': 69.26,
#    'night': 53.82,
#    'eve': 65.14,
#    'morn': 60.04},
#   'feels_like': {'day': 63.95, 'night': 52.52, 'eve': 63.99, 'morn': 59.88},
#   'pressure': 1025,
#   'humidity': 57,
#   'dew_point': 48.61,
#   'wind_speed': 9.95,
#   'wind_deg': 262,
#   'wind_gust': 26.26,
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': 30,
#   'pop': 0.7,
#   'rain': 0.37,
#   'uvi': 3}]

# %%
import requests
# Now I can write the entire program...
location = input("Where are you? (eg. Syracuse, NY) : ")
geodata = geocode(location)
lat,lon = geodata[0]['lat'], geodata[0]['lon']
weather = getweather(lat,lon)
current = weather['current']
print(f"Current conditions in {location} are {current['weather'][0]['description']} with a temperature of {current['temp']} degrees.")
# Out:
# Where are you? (eg. Syracuse, NY) : Miami, FL
# Current conditions in Miami, FL are clear sky with a temperature of 84.58 degrees.

# %%
from IPython.display import display, HTML
from ipywidgets import interact_manual
import requests

display(HTML("<h1>Weather Forecaster</h1>"))
@interact_manual(location="")
def main(location):
    geodata = geocode(location)
    lat,lon = geodata[0]['lat'], geodata[0]['lon']
    weather = getweather(lat,lon)
    current = weather['current']
    print(f"Current conditions in {location} are {current['weather'][0]['description']} with a temperature of {current['temp']} degrees.")
# Out:
# <h1>Weather Forecaster</h1>
# interactive(children=(Text(value='', description='location'), Button(description='Run Interact', style=ButtonS…
