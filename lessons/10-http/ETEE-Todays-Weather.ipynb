# %% [markdown]
# # End-To-End Example: Today's Weather
#
# This example will input a location and then output today's current weather conditions at that location.
#
# To complete this example we will use the following API's
#
# - https://www.openstreetmap.org/ Geocode api to get GPS coordinates for a location eg. Syracuse, NY
# - https://openweathermap.org/ forecast api to get the currnt weather conditions for those GPS coordinates

# %%
# Todo list
# input a location eg. Syracuse, ny
# use the google geocode api to get a lat/lng
# use the darksky api and lat/lng to get current weather conditions
# output current weather conditions (temperature and summary (rain, snow, etc...))

# %%
import requests

# %%
def geocode(location):
    query_string = {'q' : location, 'format': 'json'}
    url='https://nominatim.openstreetmap.org/search' 
    response = requests.get(url, params = query_string)
    response.raise_for_status()
    geodata = response.json()
    return geodata
        
# Testing with syracuse, NY 
geocode('Syracuse, NY')
# Out:
# [{'place_id': 298364595,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 174916,
#   'boundingbox': ['42.984165', '43.086121', '-76.204629', '-76.074273'],
#   'lat': '43.0481221',
#   'lon': '-76.1474244',
#   'display_name': 'City of Syracuse, Onondaga County, New York, United States',
#   'class': 'boundary',
#   'type': 'administrative',
#   'importance': 0.6767762857760726,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/poi_boundary_administrative.p.20.png'},
#  {'place_id': 67220594,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'node',
#   'osm_id': 6241108067,
#   'boundingbox': ['43.0718312', '43.0818312', '-76.1744003', '-76.1644003'],
#   'lat': '43.0768312',
#   'lon': '-76.1694003',
#   'display_name': 'Syracuse, 131, NBT Bank Parkway, City of Syracuse, Onondaga County, New York, 13208, United States',
#   'class': 'railway',
#   'type': 'station',
#   'importance': 0.4272524353626238,
#   'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/transport_train_station2.p.20.png'},
#  {'place_id': 36528029,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#   'osm_type': 'node',
#   'osm_id': 2997656284,
#   'boundingbox': ['43.0770382', '43.0771382', '-76.1700021', '-76.1699021'],
#   'lat': '43.0770882',
#   'lon': '-76.1699521',
#   'display_name': 'Syracuse, Walsh Circle, City of Syracuse, Onondaga County, New York, 13290, United States',
#   'class': 'railway',
#   'type': 'stop',
#   'importance': 0.11000999999999997}]

# %%
def getweather(lat,lon):
    key = '67f9d45c32dd086df27f2b7a90370a8e' # sign up for your own key at https://openweathermap.org/ 
    query_string = { 'lat' : lat, 'lon': lon, 'appid' : key, 'units' : 'imperial'}
    url='https://api.openweathermap.org/data/2.5/onecall' 
    response = requests.get(url, params=query_string)
    response.raise_for_status()
    #print (response.url)
    weather = response.json()
    return weather

# Testing with syracuse, NY coordinates
getweather( 43.0481221, -76.1474244 )
# Out:
# {'lat': 43.0481,
#  'lon': -76.1474,
#  'timezone': 'America/New_York',
#  'timezone_offset': -14400,
#  'current': {'dt': 1680547141,
#   'sunrise': 1680518602,
#   'sunset': 1680564727,
#   'temp': 62.58,
#   'feels_like': 60.22,
#   'pressure': 1008,
#   'humidity': 36,
#   'dew_point': 35.29,
#   'uvi': 1.99,
#   'clouds': 20,
#   'visibility': 10000,
#   'wind_speed': 19.57,
#   'wind_deg': 210,
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}]},
#  'minutely': [{'dt': 1680547200, 'precipitation': 0},
#   {'dt': 1680547260, 'precipitation': 0},
#   {'dt': 1680547320, 'precipitation': 0},
#   {'dt': 1680547380, 'precipitation': 0},
#   {'dt': 1680547440, 'precipitation': 0},
#   {'dt': 1680547500, 'precipitation': 0},
#   {'dt': 1680547560, 'precipitation': 0},
#   {'dt': 1680547620, 'precipitation': 0},
#   {'dt': 1680547680, 'precipitation': 0},
#   {'dt': 1680547740, 'precipitation': 0},
#   {'dt': 1680547800, 'precipitation': 0},
#   {'dt': 1680547860, 'precipitation': 0},
#   {'dt': 1680547920, 'precipitation': 0},
#   {'dt': 1680547980, 'precipitation': 0},
#   {'dt': 1680548040, 'precipitation': 0},
#   {'dt': 1680548100, 'precipitation': 0},
#   {'dt': 1680548160, 'precipitation': 0},
#   {'dt': 1680548220, 'precipitation': 0},
#   {'dt': 1680548280, 'precipitation': 0},
#   {'dt': 1680548340, 'precipitation': 0},
#   {'dt': 1680548400, 'precipitation': 0},
#   {'dt': 1680548460, 'precipitation': 0},
#   {'dt': 1680548520, 'precipitation': 0},
#   {'dt': 1680548580, 'precipitation': 0},
#   {'dt': 1680548640, 'precipitation': 0},
#   {'dt': 1680548700, 'precipitation': 0},
#   {'dt': 1680548760, 'precipitation': 0},
#   {'dt': 1680548820, 'precipitation': 0},
#   {'dt': 1680548880, 'precipitation': 0},
#   {'dt': 1680548940, 'precipitation': 0},
#   {'dt': 1680549000, 'precipitation': 0},
#   {'dt': 1680549060, 'precipitation': 0},
#   {'dt': 1680549120, 'precipitation': 0},
#   {'dt': 1680549180, 'precipitation': 0},
#   {'dt': 1680549240, 'precipitation': 0},
#   {'dt': 1680549300, 'precipitation': 0},
#   {'dt': 1680549360, 'precipitation': 0},
#   {'dt': 1680549420, 'precipitation': 0},
#   {'dt': 1680549480, 'precipitation': 0},
#   {'dt': 1680549540, 'precipitation': 0},
#   {'dt': 1680549600, 'precipitation': 0},
#   {'dt': 1680549660, 'precipitation': 0},
#   {'dt': 1680549720, 'precipitation': 0},
#   {'dt': 1680549780, 'precipitation': 0},
#   {'dt': 1680549840, 'precipitation': 0},
#   {'dt': 1680549900, 'precipitation': 0},
#   {'dt': 1680549960, 'precipitation': 0},
#   {'dt': 1680550020, 'precipitation': 0},
#   {'dt': 1680550080, 'precipitation': 0},
#   {'dt': 1680550140, 'precipitation': 0},
#   {'dt': 1680550200, 'precipitation': 0},
#   {'dt': 1680550260, 'precipitation': 0},
#   {'dt': 1680550320, 'precipitation': 0},
#   {'dt': 1680550380, 'precipitation': 0},
#   {'dt': 1680550440, 'precipitation': 0},
#   {'dt': 1680550500, 'precipitation': 0},
#   {'dt': 1680550560, 'precipitation': 0},
#   {'dt': 1680550620, 'precipitation': 0},
#   {'dt': 1680550680, 'precipitation': 0},
#   {'dt': 1680550740, 'precipitation': 0},
#   {'dt': 1680550800, 'precipitation': 0}],
#  'hourly': [{'dt': 1680544800,
#    'temp': 61.81,
#    'feels_like': 59.52,
#    'pressure': 1008,
#    'humidity': 39,
#    'dew_point': 36.63,
#    'uvi': 3.53,
#    'clouds': 30,
#    'visibility': 10000,
#    'wind_speed': 18.7,
#    'wind_deg': 207,
#    'wind_gust': 30.85,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0},
#   {'dt': 1680548400,
#    'temp': 62.58,
#    'feels_like': 60.22,
#    'pressure': 1008,
#    'humidity': 36,
#    'dew_point': 35.29,
#    'uvi': 1.99,
#    'clouds': 20,
#    'visibility': 10000,
#    'wind_speed': 16.42,
#    'wind_deg': 214,
#    'wind_gust': 30.44,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'pop': 0},
#   {'dt': 1680552000,
#    'temp': 61.95,
#    'feels_like': 59.77,
#    'pressure': 1008,
#    'humidity': 41,
#    'dew_point': 38.01,
#    'uvi': 1.31,
#    'clouds': 29,
#    'visibility': 10000,
#    'wind_speed': 13.4,
#    'wind_deg': 228,
#    'wind_gust': 28.19,
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'pop': 0.16},
#   {'dt': 1680555600,
#    'temp': 58.66,
#    'feels_like': 56.71,
#    'pressure': 1009,
#    'humidity': 53,
#    'dew_point': 41.59,
#    'uvi': 0.67,
#    'clouds': 43,
#    'visibility': 8252,
#    'wind_speed': 11.45,
#    'wind_deg': 280,
#    'wind_gust': 26.24,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'pop': 0.52,
#    'rain': {'1h': 1.02}},
#   {'dt': 1680559200,
#    'temp': 53.47,
#    'feels_like': 51.76,
#    'pressure': 1011,
#    'humidity': 69,
#    'dew_point': 43.57,
#    'uvi': 0.35,
#    'clouds': 58,
#    'visibility': 10000,
#    'wind_speed': 3.8,
#    'wind_deg': 300,
#    'wind_gust': 11.5,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'pop': 0.88,
#    'rain': {'1h': 2.19}},
#   {'dt': 1680562800,
#    'temp': 50.09,
#    'feels_like': 48.56,
#    'pressure': 1013,
#    'humidity': 80,
#    'dew_point': 44.17,
#    'uvi': 0,
#    'clouds': 74,
#    'visibility': 10000,
#    'wind_speed': 4.18,
#    'wind_deg': 308,
#    'wind_gust': 14.65,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.94,
#    'rain': {'1h': 0.37}},
#   {'dt': 1680566400,
#    'temp': 45.59,
#    'feels_like': 44.06,
#    'pressure': 1015,
#    'humidity': 93,
#    'dew_point': 42.75,
#    'uvi': 0,
#    'clouds': 89,
#    'visibility': 10000,
#    'wind_speed': 3.67,
#    'wind_deg': 252,
#    'wind_gust': 10.67,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'pop': 0.96,
#    'rain': {'1h': 1.11}},
#   {'dt': 1680570000,
#    'temp': 44.92,
#    'feels_like': 43.56,
#    'pressure': 1016,
#    'humidity': 95,
#    'dew_point': 42.73,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 8358,
#    'wind_speed': 3.38,
#    'wind_deg': 224,
#    'wind_gust': 7.43,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'pop': 0.85,
#    'rain': {'1h': 1.54}},
#   {'dt': 1680573600,
#    'temp': 44.82,
#    'feels_like': 42.17,
#    'pressure': 1016,
#    'humidity': 96,
#    'dew_point': 42.85,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 7599,
#    'wind_speed': 4.94,
#    'wind_deg': 177,
#    'wind_gust': 6.58,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'pop': 0.86,
#    'rain': {'1h': 1.89}},
#   {'dt': 1680577200,
#    'temp': 44.74,
#    'feels_like': 43.18,
#    'pressure': 1016,
#    'humidity': 96,
#    'dew_point': 42.84,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 8848,
#    'wind_speed': 3.56,
#    'wind_deg': 176,
#    'wind_gust': 5.86,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'pop': 0.96,
#    'rain': {'1h': 2.09}},
#   {'dt': 1680580800,
#    'temp': 44.74,
#    'feels_like': 43.52,
#    'pressure': 1016,
#    'humidity': 95,
#    'dew_point': 42.44,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 3.2,
#    'wind_deg': 213,
#    'wind_gust': 3.98,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 1,
#    'rain': {'1h': 0.57}},
#   {'dt': 1680584400,
#    'temp': 44.46,
#    'feels_like': 44.46,
#    'pressure': 1017,
#    'humidity': 94,
#    'dew_point': 41.85,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 8041,
#    'wind_speed': 1.97,
#    'wind_deg': 294,
#    'wind_gust': 3.94,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'pop': 1,
#    'rain': {'1h': 1.11}},
#   {'dt': 1680588000,
#    'temp': 42.93,
#    'feels_like': 39.56,
#    'pressure': 1016,
#    'humidity': 95,
#    'dew_point': 40.8,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 7148,
#    'wind_speed': 5.5,
#    'wind_deg': 25,
#    'wind_gust': 8.88,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'pop': 1,
#    'rain': {'1h': 2}},
#   {'dt': 1680591600,
#    'temp': 41.04,
#    'feels_like': 39.27,
#    'pressure': 1017,
#    'humidity': 97,
#    'dew_point': 39.4,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 2360,
#    'wind_speed': 3.24,
#    'wind_deg': 28,
#    'wind_gust': 6.8,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'pop': 0.99,
#    'rain': {'1h': 3.54}},
#   {'dt': 1680595200,
#    'temp': 40.59,
#    'feels_like': 37.81,
#    'pressure': 1017,
#    'humidity': 97,
#    'dew_point': 38.91,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 5979,
#    'wind_speed': 4.21,
#    'wind_deg': 49,
#    'wind_gust': 6.17,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'pop': 0.99,
#    'rain': {'1h': 2.24}},
#   {'dt': 1680598800,
#    'temp': 40.3,
#    'feels_like': 40.3,
#    'pressure': 1018,
#    'humidity': 97,
#    'dew_point': 38.57,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 2.53,
#    'wind_deg': 72,
#    'wind_gust': 4.72,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'pop': 0.98,
#    'rain': {'1h': 1.3}},
#   {'dt': 1680602400,
#    'temp': 40.19,
#    'feels_like': 37.65,
#    'pressure': 1018,
#    'humidity': 97,
#    'dew_point': 38.66,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 4157,
#    'wind_speed': 3.87,
#    'wind_deg': 107,
#    'wind_gust': 6.2,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'pop': 0.99,
#    'rain': {'1h': 3.24}},
#   {'dt': 1680606000,
#    'temp': 40.69,
#    'feels_like': 38.88,
#    'pressure': 1018,
#    'humidity': 97,
#    'dew_point': 39.11,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 7207,
#    'wind_speed': 3.24,
#    'wind_deg': 104,
#    'wind_gust': 6.15,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'pop': 0.99,
#    'rain': {'1h': 2.96}},
#   {'dt': 1680609600,
#    'temp': 40.96,
#    'feels_like': 38.14,
#    'pressure': 1018,
#    'humidity': 97,
#    'dew_point': 39.36,
#    'uvi': 0.06,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 4.34,
#    'wind_deg': 52,
#    'wind_gust': 6.53,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'pop': 1,
#    'rain': {'1h': 1.02}},
#   {'dt': 1680613200,
#    'temp': 41.16,
#    'feels_like': 39.24,
#    'pressure': 1019,
#    'humidity': 97,
#    'dew_point': 39.51,
#    'uvi': 0.18,
#    'clouds': 100,
#    'visibility': 5682,
#    'wind_speed': 3.4,
#    'wind_deg': 70,
#    'wind_gust': 6.22,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'pop': 0.84,
#    'rain': {'1h': 1.17}},
#   {'dt': 1680616800,
#    'temp': 41.5,
#    'feels_like': 39.63,
#    'pressure': 1019,
#    'humidity': 96,
#    'dew_point': 39.7,
#    'uvi': 0.37,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 3.4,
#    'wind_deg': 74,
#    'wind_gust': 6.04,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'pop': 0.81,
#    'rain': {'1h': 1.05}},
#   {'dt': 1680620400,
#    'temp': 43.05,
#    'feels_like': 40.39,
#    'pressure': 1019,
#    'humidity': 94,
#    'dew_point': 40.51,
#    'uvi': 0.59,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 4.56,
#    'wind_deg': 47,
#    'wind_gust': 5.7,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.77,
#    'rain': {'1h': 0.2}},
#   {'dt': 1680624000,
#    'temp': 44.76,
#    'feels_like': 41.68,
#    'pressure': 1019,
#    'humidity': 91,
#    'dew_point': 41.41,
#    'uvi': 1.37,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 5.59,
#    'wind_deg': 54,
#    'wind_gust': 6.82,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.69},
#   {'dt': 1680627600,
#    'temp': 46.67,
#    'feels_like': 44.26,
#    'pressure': 1018,
#    'humidity': 87,
#    'dew_point': 42.26,
#    'uvi': 1.5,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 5.08,
#    'wind_deg': 67,
#    'wind_gust': 6.93,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.64},
#   {'dt': 1680631200,
#    'temp': 46.04,
#    'feels_like': 42.13,
#    'pressure': 1019,
#    'humidity': 89,
#    'dew_point': 42.21,
#    'uvi': 1.41,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 7.58,
#    'wind_deg': 24,
#    'wind_gust': 9.04,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.63},
#   {'dt': 1680634800,
#    'temp': 43.45,
#    'feels_like': 38.62,
#    'pressure': 1020,
#    'humidity': 93,
#    'dew_point': 40.75,
#    'uvi': 0.63,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 8.34,
#    'wind_deg': 27,
#    'wind_gust': 14.54,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.13},
#   {'dt': 1680638400,
#    'temp': 42.84,
#    'feels_like': 38.95,
#    'pressure': 1021,
#    'humidity': 94,
#    'dew_point': 40.41,
#    'uvi': 0.42,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 6.31,
#    'wind_deg': 46,
#    'wind_gust': 15.23,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.17},
#   {'dt': 1680642000,
#    'temp': 42.66,
#    'feels_like': 38.44,
#    'pressure': 1021,
#    'humidity': 95,
#    'dew_point': 40.35,
#    'uvi': 0.21,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 6.82,
#    'wind_deg': 59,
#    'wind_gust': 17.16,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.26,
#    'rain': {'1h': 0.19}},
#   {'dt': 1680645600,
#    'temp': 42.55,
#    'feels_like': 38.57,
#    'pressure': 1021,
#    'humidity': 94,
#    'dew_point': 40.08,
#    'uvi': 0.09,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 6.38,
#    'wind_deg': 64,
#    'wind_gust': 17.98,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.42,
#    'rain': {'1h': 0.3}},
#   {'dt': 1680649200,
#    'temp': 42.46,
#    'feels_like': 38.91,
#    'pressure': 1022,
#    'humidity': 94,
#    'dew_point': 39.96,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 5.64,
#    'wind_deg': 64,
#    'wind_gust': 17.47,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.38,
#    'rain': {'1h': 0.3}},
#   {'dt': 1680652800,
#    'temp': 42.33,
#    'feels_like': 39.38,
#    'pressure': 1023,
#    'humidity': 94,
#    'dew_point': 39.99,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 4.76,
#    'wind_deg': 62,
#    'wind_gust': 16.24,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 0.42,
#    'rain': {'1h': 0.14}},
#   {'dt': 1680656400,
#    'temp': 42.44,
#    'feels_like': 39.92,
#    'pressure': 1023,
#    'humidity': 94,
#    'dew_point': 40.1,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 4.25,
#    'wind_deg': 63,
#    'wind_gust': 12.48,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.1},
#   {'dt': 1680660000,
#    'temp': 42.49,
#    'feels_like': 40.51,
#    'pressure': 1023,
#    'humidity': 95,
#    'dew_point': 40.24,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 3.65,
#    'wind_deg': 49,
#    'wind_gust': 8.32,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0.08},
#   {'dt': 1680663600,
#    'temp': 42.46,
#    'feels_like': 40.42,
#    'pressure': 1023,
#    'humidity': 95,
#    'dew_point': 40.28,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 3.71,
#    'wind_deg': 41,
#    'wind_gust': 6.8,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1680667200,
#    'temp': 42.57,
#    'feels_like': 39.99,
#    'pressure': 1023,
#    'humidity': 95,
#    'dew_point': 40.39,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 4.34,
#    'wind_deg': 77,
#    'wind_gust': 9.44,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1680670800,
#    'temp': 43.03,
#    'feels_like': 39.72,
#    'pressure': 1022,
#    'humidity': 95,
#    'dew_point': 40.73,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 5.46,
#    'wind_deg': 95,
#    'wind_gust': 11.61,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1680674400,
#    'temp': 42.98,
#    'feels_like': 39.83,
#    'pressure': 1022,
#    'humidity': 94,
#    'dew_point': 40.55,
#    'uvi': 0,
#    'clouds': 99,
#    'visibility': 10000,
#    'wind_speed': 5.21,
#    'wind_deg': 101,
#    'wind_gust': 9.42,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1680678000,
#    'temp': 42.42,
#    'feels_like': 39.25,
#    'pressure': 1021,
#    'humidity': 94,
#    'dew_point': 40.12,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 5.08,
#    'wind_deg': 126,
#    'wind_gust': 8.3,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1680681600,
#    'temp': 43.02,
#    'feels_like': 39.81,
#    'pressure': 1020,
#    'humidity': 95,
#    'dew_point': 40.66,
#    'uvi': 0,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 5.3,
#    'wind_deg': 116,
#    'wind_gust': 10.6,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1680685200,
#    'temp': 44.04,
#    'feels_like': 40.37,
#    'pressure': 1020,
#    'humidity': 95,
#    'dew_point': 41.86,
#    'uvi': 0,
#    'clouds': 97,
#    'visibility': 10000,
#    'wind_speed': 6.35,
#    'wind_deg': 95,
#    'wind_gust': 12.64,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'pop': 0},
#   {'dt': 1680688800,
#    'temp': 44.83,
#    'feels_like': 41.7,
#    'pressure': 1020,
#    'humidity': 96,
#    'dew_point': 42.75,
#    'uvi': 0,
#    'clouds': 96,
#    'visibility': 10000,
#    'wind_speed': 5.68,
#    'wind_deg': 102,
#    'wind_gust': 13.02,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'pop': 0.3,
#    'rain': {'1h': 0.11}},
#   {'dt': 1680692400,
#    'temp': 45.48,
#    'feels_like': 41.72,
#    'pressure': 1019,
#    'humidity': 96,
#    'dew_point': 43.48,
#    'uvi': 0,
#    'clouds': 97,
#    'visibility': 10000,
#    'wind_speed': 7.05,
#    'wind_deg': 113,
#    'wind_gust': 18.34,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.27},
#   {'dt': 1680696000,
#    'temp': 50.02,
#    'feels_like': 49.08,
#    'pressure': 1018,
#    'humidity': 93,
#    'dew_point': 47.25,
#    'uvi': 0.19,
#    'clouds': 98,
#    'visibility': 10000,
#    'wind_speed': 9.57,
#    'wind_deg': 133,
#    'wind_gust': 29.64,
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'pop': 0.33},
#   {'dt': 1680699600,
#    'temp': 54.01,
#    'feels_like': 53.38,
#    'pressure': 1017,
#    'humidity': 91,
#    'dew_point': 50.68,
#    'uvi': 0.42,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 11.39,
#    'wind_deg': 158,
#    'wind_gust': 33.46,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.77,
#    'rain': {'1h': 0.35}},
#   {'dt': 1680703200,
#    'temp': 55.85,
#    'feels_like': 55.42,
#    'pressure': 1016,
#    'humidity': 91,
#    'dew_point': 52.38,
#    'uvi': 0.87,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 14.94,
#    'wind_deg': 159,
#    'wind_gust': 38.81,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.92,
#    'rain': {'1h': 0.72}},
#   {'dt': 1680706800,
#    'temp': 58.87,
#    'feels_like': 58.6,
#    'pressure': 1016,
#    'humidity': 88,
#    'dew_point': 54.45,
#    'uvi': 1.39,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 15.75,
#    'wind_deg': 172,
#    'wind_gust': 38.59,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.77,
#    'rain': {'1h': 0.5}},
#   {'dt': 1680710400,
#    'temp': 60.3,
#    'feels_like': 60.12,
#    'pressure': 1016,
#    'humidity': 87,
#    'dew_point': 55.51,
#    'uvi': 0.69,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 14.79,
#    'wind_deg': 173,
#    'wind_gust': 35.75,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.7,
#    'rain': {'1h': 0.4}},
#   {'dt': 1680714000,
#    'temp': 60.64,
#    'feels_like': 60.49,
#    'pressure': 1016,
#    'humidity': 87,
#    'dew_point': 55.94,
#    'uvi': 0.76,
#    'clouds': 100,
#    'visibility': 10000,
#    'wind_speed': 15.61,
#    'wind_deg': 169,
#    'wind_gust': 36.19,
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'pop': 0.72,
#    'rain': {'1h': 0.61}}],
#  'daily': [{'dt': 1680541200,
#    'sunrise': 1680518602,
#    'sunset': 1680564727,
#    'moonrise': 1680555840,
#    'moonset': 1680515940,
#    'moon_phase': 0.42,
#    'temp': {'day': 59.63,
#     'min': 30.18,
#     'max': 62.58,
#     'night': 44.74,
#     'eve': 50.09,
#     'morn': 35.94},
#    'feels_like': {'day': 57.22, 'night': 43.18, 'eve': 48.56, 'morn': 28.06},
#    'pressure': 1009,
#    'humidity': 41,
#    'dew_point': 35.92,
#    'wind_speed': 19.73,
#    'wind_deg': 189,
#    'wind_gust': 39.46,
#    'weather': [{'id': 616,
#      'main': 'Snow',
#      'description': 'rain and snow',
#      'icon': '13d'}],
#    'clouds': 40,
#    'pop': 0.96,
#    'rain': 10.21,
#    'snow': 0.12,
#    'uvi': 3.76},
#   {'dt': 1680627600,
#    'sunrise': 1680604897,
#    'sunset': 1680651196,
#    'moonrise': 1680646140,
#    'moonset': 1680603480,
#    'moon_phase': 0.45,
#    'temp': {'day': 46.67,
#     'min': 40.19,
#     'max': 46.67,
#     'night': 42.46,
#     'eve': 42.46,
#     'morn': 40.69},
#    'feels_like': {'day': 44.26, 'night': 40.42, 'eve': 38.91, 'morn': 38.88},
#    'pressure': 1018,
#    'humidity': 87,
#    'dew_point': 42.26,
#    'wind_speed': 8.34,
#    'wind_deg': 27,
#    'wind_gust': 17.98,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': 100,
#    'pop': 1,
#    'rain': 21.33,
#    'uvi': 1.5},
#   {'dt': 1680714000,
#    'sunrise': 1680691192,
#    'sunset': 1680737665,
#    'moonrise': 1680736440,
#    'moonset': 1680690960,
#    'moon_phase': 0.48,
#    'temp': {'day': 60.64,
#     'min': 42.42,
#     'max': 63.03,
#     'night': 63.03,
#     'eve': 61.43,
#     'morn': 45.48},
#    'feels_like': {'day': 60.49, 'night': 63.21, 'eve': 61.41, 'morn': 41.72},
#    'pressure': 1016,
#    'humidity': 87,
#    'dew_point': 55.94,
#    'wind_speed': 19.33,
#    'wind_deg': 188,
#    'wind_gust': 42.48,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': 100,
#    'pop': 1,
#    'rain': 15.65,
#    'uvi': 1.39},
#   {'dt': 1680800400,
#    'sunrise': 1680777488,
#    'sunset': 1680824134,
#    'moonrise': 1680826920,
#    'moonset': 1680778560,
#    'moon_phase': 0.5,
#    'temp': {'day': 52.92,
#     'min': 42.35,
#     'max': 65.39,
#     'night': 42.35,
#     'eve': 44.67,
#     'morn': 53.65},
#    'feels_like': {'day': 50.83, 'night': 36.12, 'eve': 38.86, 'morn': 52.95},
#    'pressure': 1022,
#    'humidity': 62,
#    'dew_point': 39.31,
#    'wind_speed': 18.21,
#    'wind_deg': 188,
#    'wind_gust': 39.1,
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': 100,
#    'pop': 1,
#    'rain': 4.33,
#    'uvi': 4.53},
#   {'dt': 1680886800,
#    'sunrise': 1680863784,
#    'sunset': 1680910604,
#    'moonrise': 1680917520,
#    'moonset': 1680866220,
#    'moon_phase': 0.55,
#    'temp': {'day': 45.05,
#     'min': 35.89,
#     'max': 45.05,
#     'night': 36.09,
#     'eve': 38.61,
#     'morn': 35.89},
#    'feels_like': {'day': 38.82, 'night': 36.09, 'eve': 35.94, 'morn': 28.36},
#    'pressure': 1031,
#    'humidity': 47,
#    'dew_point': 25.29,
#    'wind_speed': 13.78,
#    'wind_deg': 282,
#    'wind_gust': 27.11,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': 6,
#    'pop': 0,
#    'uvi': 5.42},
#   {'dt': 1680973200,
#    'sunrise': 1680950081,
#    'sunset': 1680997073,
#    'moonrise': 1681008300,
#    'moonset': 1680954060,
#    'moon_phase': 0.58,
#    'temp': {'day': 46.02,
#     'min': 33.85,
#     'max': 46.02,
#     'night': 33.85,
#     'eve': 36.52,
#     'morn': 34.5},
#    'feels_like': {'day': 41.86, 'night': 33.85, 'eve': 33.42, 'morn': 30.96},
#    'pressure': 1032,
#    'humidity': 44,
#    'dew_point': 24.42,
#    'wind_speed': 9.73,
#    'wind_deg': 333,
#    'wind_gust': 10.8,
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'clouds': 68,
#    'pop': 0.38,
#    'snow': 0.58,
#    'uvi': 0.37},
#   {'dt': 1681059600,
#    'sunrise': 1681036378,
#    'sunset': 1681083542,
#    'moonrise': 1681099200,
#    'moonset': 1681042260,
#    'moon_phase': 0.62,
#    'temp': {'day': 51.93,
#     'min': 32.36,
#     'max': 51.93,
#     'night': 37.38,
#     'eve': 40.3,
#     'morn': 36.81},
#    'feels_like': {'day': 48.56, 'night': 34.29, 'eve': 40.3, 'morn': 36.81},
#    'pressure': 1030,
#    'humidity': 37,
#    'dew_point': 25.61,
#    'wind_speed': 8.28,
#    'wind_deg': 321,
#    'wind_gust': 9.82,
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': 6,
#    'pop': 0,
#    'uvi': 1},
#   {'dt': 1681146000,
#    'sunrise': 1681122675,
#    'sunset': 1681170012,
#    'moonrise': 0,
#    'moonset': 1681130940,
#    'moon_phase': 0.65,
#    'temp': {'day': 62.42,
#     'min': 34.88,
#     'max': 63.57,
#     'night': 51.39,
#     'eve': 52.61,
#     'morn': 39.65},
#    'feels_like': {'day': 60.06, 'night': 48.9, 'eve': 50.4, 'morn': 35.91},
#    'pressure': 1024,
#    'humidity': 36,
#    'dew_point': 34.63,
#    'wind_speed': 14.56,
#    'wind_deg': 179,
#    'wind_gust': 35.3,
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': 13,
#    'pop': 0,
#    'uvi': 1}]}

# %%
# then test them here to figue out how to extract from the dictionary
geodata = geocode('Syracuse, NY')
lat = geodata[0]['lat']
lon = geodata[0]['lon']
weather = getweather(lat, lon)
weather.keys()
# Out:
# dict_keys(['lat', 'lon', 'timezone', 'timezone_offset', 'current', 'minutely', 'hourly', 'daily'])

# %%
weather['daily']

# %%
import requests
# Now I can write the entire program...
location = input("Where are you? (eg. Syracuse, NY) : ")
geodata = geocode(location)
lat,lon = geodata[0]['lat'], geodata[0]['lon']
weather = getweather(lat,lon)
current = weather['current']
print(f"Current conditions in {location} are {current['weather'][0]['description']} with a temperature of {current['temp']} degrees.")

# %%
from IPython.display import display, HTML
from ipywidgets import interact_manual
import requests

display(HTML("<h1>Weather Forecaster</h1>"))
@interact_manual(location="")
def main(location):
    geodata = geocode(location)
    lat,lon = geodata[0]['lat'], geodata[0]['lon']
    weather = getweather(lat,lon)
    current = weather['current']
    print(f"Current conditions in {location} are {current['weather'][0]['description']} with a temperature of {current['temp']} degrees.")
# Out:
# <h1>Weather Forecaster</h1>
# interactive(children=(Text(value='', description='location'), Button(description='Run Interact', style=ButtonS…
