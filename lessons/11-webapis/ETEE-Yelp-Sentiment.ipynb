# %% [markdown]
# ### Get the most positive and negative online reviews about a business
#
# How well to the ratings match the sentiment of the review text?
#
# - Learn the Yelp API https://www.yelp.com/developers
# - Search for a business and get reviews
# - Use Azure Text Analytics https://docs.microsoft.com/en-us/azure/cognitive-services/text-analytics/
# - Get sentiment of reviews
# - Time permitting do negative
# - Demonstrate the problem simplification approach

# %%
import requests
from IPython.display import display, Image, HTML
from ipywidgets import widgets, interact_manual

# %% [markdown]
# ## Sentiment

# %%
def get_sentiment(text):
    key = '045fae3d312d4f30aee929a8832b2ad9'
    endpoint = 'https://ist256-mafudge-cogsvcs.cognitiveservices.azure.com/'
    url = f'{endpoint}text/analytics/v3.0/sentiment'
    header = { 'Ocp-Apim-Subscription-Key' : key}
    
    documents = {"documents": [{"id": "1", "language": "en","text": text}]}

    response = requests.post(url, headers=header, json=documents)
    response.raise_for_status()
    data = response.json()
    
    return data['documents'][0]['sentiment']

print(get_sentiment("I do not like green edds and ham. I do not like them sam I am."))
print(get_sentiment("I like scotch. Scotchy-scotch, scotch."))
# Out:
# neutral
# positive

# %%
# search 
yelp_api_key = "PKt-vCvtw-G0WGjf-DKITO0I07fFi6rTt6WuT2vfecT3xCzSMaD1Uf2uKPuN-1A_1gwRZ15qx4DBEWDyYpV4p_3yh-aqAiPUXGxIkken2gCAq8-sXO4W4zh6ZZ_TW3Yx"
url = "https://api.yelp.com/v3/businesses/search"
header = { "Authorization" : f"Bearer {yelp_api_key}" }
query = { "term" : "thai", "location" : "Syracuse, NY" }
response = requests.get(url, params = query, headers = header)
response.json()
# Out:
# {'businesses': [{'id': 'su6OgvIv5u5Wx_c0adqPiw',
#    'alias': 'thai-flavor-syracuse',
#    'name': 'Thai Flavor',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AdaoVhN3_Kk6NyzQ3gwJiQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-flavor-syracuse?adjust_creative=H2mBmGHSsANIEiZZaA4ZyA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=H2mBmGHSsANIEiZZaA4ZyA',
#    'review_count': 160,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.05566, 'longitude': -76.0918},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2863 Erie Blvd E',
#     'address2': '',
#     'address3': '',
#     'city': 'Syracuse',
#     'zip_code': '13224',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2863 Erie Blvd E', 'Syracuse, NY 13224']},
#    'phone': '+13152511366',
#    'display_phone': '(315) 251-1366',
#    'distance': 4470.628976565158},
#   {'id': 'si7cscm8H6pr57KsVSkhow',
#    'alias': 'thai-thai-cuisine-syracuse',
#    'name': 'Thai Thai Cuisine',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SSlekoMQyGii_gFWzJXYRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-thai-cuisine-syracuse?adjust_creative=H2mBmGHSsANIEiZZaA4ZyA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=H2mBmGHSsANIEiZZaA4ZyA',
#    'review_count': 93,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.055, 'longitude': -76.0785},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '3138 Erie Blvd E',
#     'address2': '',
#     'address3': None,
#     'city': 'Syracuse',
#     'zip_code': '13214',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3138 Erie Blvd E', 'Syracuse, NY 13214']},
#    'phone': '+13158027660',
#    'display_phone': '(315) 802-7660',
#    'distance': 5414.1806737179795},
#   {'id': 'knoT2pa13_fSnrDAMC18Ng',
#    'alias': 'thai-love-ny-syracuse',
#    'name': 'Thai Love NY',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Zf7FKu0w_5MvsgTfkBA1HA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-love-ny-syracuse?adjust_creative=H2mBmGHSsANIEiZZaA4ZyA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=H2mBmGHSsANIEiZZaA4ZyA',
#    'review_count': 246,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.097, 'longitude': -76.14502},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2822 Lemoyne Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Syracuse',
#     'zip_code': '13211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2822 Lemoyne Ave', 'Syracuse, NY 13211']},
#    'phone': '+13159285659',
#    'display_phone': '(315) 928-5659',
#    'distance': 6879.463792463255},
#   {'id': '7EOSY1UiCgAxM55nGAFagQ',
#    'alias': 'lemon-grass-syracuse',
#    'name': 'Lemon Grass',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GyofIO0unPEjVq6rbko8YQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lemon-grass-syracuse?adjust_creative=H2mBmGHSsANIEiZZaA4ZyA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=H2mBmGHSsANIEiZZaA4ZyA',
#    'review_count': 289,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.04799321023074,
#     'longitude': -76.15426127843128},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '113 Walton St',
#     'address2': '',
#     'address3': '',
#     'city': 'Syracuse',
#     'zip_code': '13202',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['113 Walton St', 'Syracuse, NY 13202']},
#    'phone': '+13154751111',
#    'display_phone': '(315) 475-1111',
#    'distance': 1865.4259286377367},
#   {'id': 'G7vAC02Zc8Nc_w3BC-tO9A',
#    'alias': 'appethaizing-clinton-square-syracuse-2',
#    'name': 'Appethaizing - Clinton Square',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/O-koQimf5qJDPmqO7Dp_lg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/appethaizing-clinton-square-syracuse-2?adjust_creative=H2mBmGHSsANIEiZZaA4ZyA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=H2mBmGHSsANIEiZZaA4ZyA',
#    'review_count': 12,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'herbsandspices', 'title': 'Herbs & Spices'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.05162, 'longitude': -76.1538099},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '208 W Genesee St',
#     'address2': '',
#     'address3': None,
#     'city': 'Syracuse',
#     'zip_code': '13202',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['208 W Genesee St', 'Syracuse, NY 13202']},
#    'phone': '+13154248424',
#    'display_phone': '(315) 424-8424',
#    'distance': 2174.7045536870196},
#   {'id': 'xkU58y1YhdcZFDqq_ENQGA',
#    'alias': 'erawan-thai-restaurant-syracuse',
#    'name': 'Erawan Thai Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ahM2S3W2EHq5R8n9Oi_h5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/erawan-thai-restaurant-syracuse?adjust_creative=H2mBmGHSsANIEiZZaA4ZyA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=H2mBmGHSsANIEiZZaA4ZyA',
#    'review_count': 143,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 43.05378, 'longitude': -76.09696},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '2724 Erie Blvd E',
#     'address2': '',
#     'address3': '',
#     'city': 'Syracuse',
#     'zip_code': '13224',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2724 Erie Blvd E', 'Syracuse, NY 13224']},
#    'phone': '+13154458152',
#    'display_phone': '(315) 445-8152',
#    'distance': 4033.0569728683486},
#   {'id': 'bPtFKkf-M4tfKixaIiseQw',
#    'alias': 'firecracker-thai-kitchen-syracuse',
#    'name': 'Firecracker Thai Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Uuv37xjac_fPAedhtbTjaA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/firecracker-thai-kitchen-syracuse?adjust_creative=H2mBmGHSsANIEiZZaA4ZyA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=H2mBmGHSsANIEiZZaA4ZyA',
#    'review_count': 17,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.04448, 'longitude': -76.1529},
#    'transactions': [],
#    'location': {'address1': '484 South Salina St',
#     'address2': None,
#     'address3': '',
#     'city': 'Syracuse',
#     'zip_code': '13202',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['484 South Salina St', 'Syracuse, NY 13202']},
#    'phone': '+13153621700',
#    'display_phone': '(315) 362-1700',
#    'distance': 1480.4057569498277},
#   {'id': 'Bkk46_S22QhYAa9S8X9uqQ',
#    'alias': 'bangkok-thai-restaurant-liverpool',
#    'name': 'Bangkok Thai Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/r0y5FSnet22IG25qYq-eiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bangkok-thai-restaurant-liverpool?adjust_creative=H2mBmGHSsANIEiZZaA4ZyA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=H2mBmGHSsANIEiZZaA4ZyA',
#    'review_count': 126,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.12826251061448,
#     'longitude': -76.22069032943091},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '7421 Oswego Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Liverpool',
#     'zip_code': '13090',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7421 Oswego Rd', 'Liverpool, NY 13090']},
#    'phone': '+13154514621',
#    'display_phone': '(315) 451-4621',
#    'distance': 12273.59188892971},
#   {'id': 'dEIWWRo_t904BSdPWFn5Mg',
#    'alias': 'khao-gaeng-by-appethaizing-syracuse',
#    'name': 'Khao Gaeng by appeThaizing',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1hhz_w1Igf43DzeMvBU0LQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/khao-gaeng-by-appethaizing-syracuse?adjust_creative=H2mBmGHSsANIEiZZaA4ZyA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=H2mBmGHSsANIEiZZaA4ZyA',
#    'review_count': 26,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'streetvendors', 'title': 'Street Vendors'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.051700592041,
#     'longitude': -76.1537933349609},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '208 W Genesee St',
#     'address2': '',
#     'address3': '',
#     'city': 'Syracuse',
#     'zip_code': '13202',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['208 W Genesee St', 'Syracuse, NY 13202']},
#    'phone': '+13154248424',
#    'display_phone': '(315) 424-8424',
#    'distance': 2174.7045536870196},
#   {'id': 'xk-ZCpvs3Jkl1Mo27JP1LA',
#    'alias': 'vietnamese-noodle-house-camillus-2',
#    'name': 'Vietnamese Noodle House',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xiHKXW1FIJnAoisKcn4SDg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vietnamese-noodle-house-camillus-2?adjust_creative=H2mBmGHSsANIEiZZaA4ZyA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=H2mBmGHSsANIEiZZaA4ZyA',
#    'review_count': 114,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.05195, 'longitude': -76.26678},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '3801 Milton Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Camillus',
#     'zip_code': '13031',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3801 Milton Ave', 'Camillus, NY 13031']},
#    'phone': '+13158709087',
#    'display_phone': '(315) 870-9087',
#    'distance': 10522.795004717096},
#   {'id': 'GkAFVWq3EfrN7CaZ-BbMJQ',
#    'alias': 'mr-noodle-and-ms-dumpling-syracuse',
#    'name': 'Mr Noodle and Ms Dumpling',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XrwmHL2Jp2BfFLQRZVR67w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mr-noodle-and-ms-dumpling-syracuse?adjust_creative=H2mBmGHSsANIEiZZaA4ZyA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=H2mBmGHSsANIEiZZaA4ZyA',
#    'review_count': 32,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.055618, 'longitude': -76.093194},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '2841 Erie Blvd E',
#     'address2': '',
#     'address3': None,
#     'city': 'Syracuse',
#     'zip_code': '13224',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2841 Erie Blvd E', 'Syracuse, NY 13224']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4386.293648600538},
#   {'id': 'QumftJQSy4PHWHQ2VM7JLA',
#    'alias': 'thai-village-of-liverpool-liverpool',
#    'name': 'Thai Village Of Liverpool',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hL-dkBSWew0_mgonYFrXcA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-village-of-liverpool-liverpool?adjust_creative=H2mBmGHSsANIEiZZaA4ZyA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=H2mBmGHSsANIEiZZaA4ZyA',
#    'review_count': 16,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.10122, 'longitude': -76.20315},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '105 1st St',
#     'address2': None,
#     'address3': '',
#     'city': 'Liverpool',
#     'zip_code': '13088',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['105 1st St', 'Liverpool, NY 13088']},
#    'phone': '+13154535500',
#    'display_phone': '(315) 453-5500',
#    'distance': 8983.574058503225},
#   {'id': '1YzNDIjiVJl7oB2MSg9qLQ',
#    'alias': 'vietnamese-noodle-house-north-syracuse-2',
#    'name': 'Vietnamese Noodle House',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_oGgDqi2_D-6Exm1bdX_7w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vietnamese-noodle-house-north-syracuse-2?adjust_creative=H2mBmGHSsANIEiZZaA4ZyA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=H2mBmGHSsANIEiZZaA4ZyA',
#    'review_count': 349,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'soup', 'title': 'Soup'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.1442322105957,
#     'longitude': -76.12822701354416},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '709 N Main St',
#     'address2': 'Ste 3',
#     'address3': '',
#     'city': 'North Syracuse',
#     'zip_code': '13212',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['709 N Main St', 'Ste 3', 'North Syracuse, NY 13212']},
#    'phone': '+13153960766',
#    'display_phone': '(315) 396-0766',
#    'distance': 12154.894226431483},
#   {'id': 'wm1KozGnm63U6tUI41bMEw',
#    'alias': 'red-chili-syracuse',
#    'name': 'Red Chili',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/s-yhj3nw1FkLLAdOJHfhQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/red-chili-syracuse?adjust_creative=H2mBmGHSsANIEiZZaA4ZyA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=H2mBmGHSsANIEiZZaA4ZyA',
#    'review_count': 272,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'},
#     {'alias': 'hotpot', 'title': 'Hot Pot'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.05417939596975,
#     'longitude': -76.09622301303737},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2740 Erie Blvd E',
#     'address2': '',
#     'address3': '',
#     'city': 'Syracuse',
#     'zip_code': '13224',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2740 Erie Blvd E', 'Syracuse, NY 13224']},
#    'phone': '+13154462882',
#    'display_phone': '(315) 446-2882',
#    'distance': 4091.2951368241256},
#   {'id': 'eXBbZTXFkjcaU5W_UYFRuQ',
#    'alias': 'taste-of-asia-syracuse',
#    'name': 'Taste Of Asia',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/28OV1Esl_sEp8yIcVUIVdw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taste-of-asia-syracuse?adjust_creative=H2mBmGHSsANIEiZZaA4ZyA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=H2mBmGHSsANIEiZZaA4ZyA',
#    'review_count': 56,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 43.0417442, 'longitude': -76.1354141},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '143 Marshall St',
#     'address2': '',
#     'address3': '',
#     'city': 'Syracuse',
#     'zip_code': '13210',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['143 Marshall St', 'Syracuse, NY 13210']},
#    'phone': '+13157515168',
#    'display_phone': '(315) 751-5168',
#    'distance': 787.7287000372039},
#   {'id': 'mV2eGVvcTzGCn_uRTOs36g',
#    'alias': 'new-century-syracuse',
#    'name': 'New Century',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/b4dpB1vp2nZ9-QxIzKYQHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-century-syracuse?adjust_creative=H2mBmGHSsANIEiZZaA4ZyA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=H2mBmGHSsANIEiZZaA4ZyA',
#    'review_count': 289,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.0681350937635,
#     'longitude': -76.1538724676234},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '518 Kirkpatrick St',
#     'address2': '',
#     'address3': '',
#     'city': 'Syracuse',
#     'zip_code': '13208',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['518 Kirkpatrick St', 'Syracuse, NY 13208']},
#    'phone': '+13154109999',
#    'display_phone': '(315) 410-9999',
#    'distance': 3844.490818407373},
#   {'id': '5NoPmtnE_6S6k0bYFTyBqw',
#    'alias': 'hi-tea-syracuse',
#    'name': 'Hi Tea',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/G9Tm-hwt3bWk6UEpXVsPPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hi-tea-syracuse?adjust_creative=H2mBmGHSsANIEiZZaA4ZyA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=H2mBmGHSsANIEiZZaA4ZyA',
#    'review_count': 59,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.04177, 'longitude': -76.13625},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '113 Marshall St',
#     'address2': '',
#     'address3': None,
#     'city': 'Syracuse',
#     'zip_code': '13210',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['113 Marshall St', 'Syracuse, NY 13210']},
#    'phone': '+13159012990',
#    'display_phone': '(315) 901-2990',
#    'distance': 771.0471068060841},
#   {'id': 'ozvpB-pEUguQlV38z_uEmg',
#    'alias': 'big-in-burma-syracuse',
#    'name': 'Big in Burma',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1QFzaYLWh_bfGpyay92NFg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/big-in-burma-syracuse?adjust_creative=H2mBmGHSsANIEiZZaA4ZyA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=H2mBmGHSsANIEiZZaA4ZyA',
#    'review_count': 14,
#    'categories': [{'alias': 'burmese', 'title': 'Burmese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.04448, 'longitude': -76.1529},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '484 South Salina St',
#     'address2': None,
#     'address3': '',
#     'city': 'Syracuse',
#     'zip_code': '13202',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['484 South Salina St', 'Syracuse, NY 13202']},
#    'phone': '+13153080454',
#    'display_phone': '(315) 308-0454',
#    'distance': 1480.4057569498277},
#   {'id': 'HuQYfB0p92_aDx4QHVH2Ow',
#    'alias': 'mitsuba-cuisine-camillus',
#    'name': 'Mitsuba Cuisine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9-VUVIlks2_kFMXMqyv_sA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mitsuba-cuisine-camillus?adjust_creative=H2mBmGHSsANIEiZZaA4ZyA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=H2mBmGHSsANIEiZZaA4ZyA',
#    'review_count': 174,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.0567018585275, 'longitude': -76.26969209393},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '174 Township Blvd',
#     'address2': 'Ste 10',
#     'address3': '',
#     'city': 'Camillus',
#     'zip_code': '13031',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['174 Township Blvd', 'Ste 10', 'Camillus, NY 13031']},
#    'phone': '+13154888898',
#    'display_phone': '(315) 488-8898',
#    'distance': 10855.863808094777},
#   {'id': '6D4EQ4nFT-N9xUAiJGSiGw',
#    'alias': 'aloha-japanese-bento-express-syracuse',
#    'name': 'Aloha Japanese Bento Express',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4HsHyfMOFWCVLtf_7_6B3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aloha-japanese-bento-express-syracuse?adjust_creative=H2mBmGHSsANIEiZZaA4ZyA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=H2mBmGHSsANIEiZZaA4ZyA',
#    'review_count': 100,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'hawaiian', 'title': 'Hawaiian'},
#     {'alias': 'burmese', 'title': 'Burmese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.0489373, 'longitude': -76.1519409},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '217 S Salina St',
#     'address2': 'Ste 3',
#     'address3': '',
#     'city': 'Syracuse',
#     'zip_code': '13202',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['217 S Salina St', 'Ste 3', 'Syracuse, NY 13202']},
#    'phone': '+13158027384',
#    'display_phone': '(315) 802-7384',
#    'distance': 1835.2633903181186}],
#  'total': 47,
#  'region': {'center': {'longitude': -76.13937377929688,
#    'latitude': 43.03522402017866}}}

# %%
# get details 
id = "xkU58y1YhdcZFDqq_ENQGA"
url = f"https://api.yelp.com/v3/businesses/{id}"
response = requests.get(url, headers = header)
response.json()
# Out:
# {'id': 'xkU58y1YhdcZFDqq_ENQGA',
#  'alias': 'erawan-thai-restaurant-syracuse',
#  'name': 'Erawan Thai Restaurant',
#  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ahM2S3W2EHq5R8n9Oi_h5g/o.jpg',
#  'is_claimed': False,
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/erawan-thai-restaurant-syracuse?adjust_creative=H2mBmGHSsANIEiZZaA4ZyA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_lookup&utm_source=H2mBmGHSsANIEiZZaA4ZyA',
#  'phone': '+13154458152',
#  'display_phone': '(315) 445-8152',
#  'review_count': 143,
#  'categories': [{'alias': 'thai', 'title': 'Thai'}],
#  'rating': 3.5,
#  'location': {'address1': '2724 Erie Blvd E',
#   'address2': '',
#   'address3': '',
#   'city': 'Syracuse',
#   'zip_code': '13224',
#   'country': 'US',
#   'state': 'NY',
#   'display_address': ['2724 Erie Blvd E', 'Syracuse, NY 13224'],
#   'cross_streets': ''},
#  'coordinates': {'latitude': 43.05378, 'longitude': -76.09696},
#  'photos': ['https://s3-media1.fl.yelpcdn.com/bphoto/ahM2S3W2EHq5R8n9Oi_h5g/o.jpg',
#   'https://s3-media3.fl.yelpcdn.com/bphoto/jrPP67uFsqrS5wmq06FCgA/o.jpg',
#   'https://s3-media3.fl.yelpcdn.com/bphoto/Vr9sKP3BojXIxV6-BuClmw/o.jpg'],
#  'price': '$$',
#  'hours': [{'open': [{'is_overnight': False,
#      'start': '1130',
#      'end': '1430',
#      'day': 0},
#     {'is_overnight': False, 'start': '1700', 'end': '2130', 'day': 0},
#     {'is_overnight': False, 'start': '1130', 'end': '1430', 'day': 1},
#     {'is_overnight': False, 'start': '1700', 'end': '2130', 'day': 1},
#     {'is_overnight': False, 'start': '1130', 'end': '1430', 'day': 2},
#     {'is_overnight': False, 'start': '1700', 'end': '2130', 'day': 2},
#     {'is_overnight': False, 'start': '1130', 'end': '1430', 'day': 3},
#     {'is_overnight': False, 'start': '1700', 'end': '2130', 'day': 3},
#     {'is_overnight': False, 'start': '1130', 'end': '1430', 'day': 4},
#     {'is_overnight': False, 'start': '1700', 'end': '2130', 'day': 4},
#     {'is_overnight': False, 'start': '1130', 'end': '1430', 'day': 5},
#     {'is_overnight': False, 'start': '1700', 'end': '2130', 'day': 5}],
#    'hours_type': 'REGULAR',
#    'is_open_now': False}],
#  'transactions': ['delivery']}

# %%
# get reviews 
id = "xkU58y1YhdcZFDqq_ENQGA"
url = f"https://api.yelp.com/v3/businesses/{id}/reviews"
response = requests.get(url, headers = header)
response.json()
# Out:
# {'reviews': [{'id': 'LccClAKHlOKkLzFyYVeAOQ',
#    'url': 'https://www.yelp.com/biz/erawan-thai-restaurant-syracuse?adjust_creative=H2mBmGHSsANIEiZZaA4ZyA&hrid=LccClAKHlOKkLzFyYVeAOQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=H2mBmGHSsANIEiZZaA4ZyA',
#    'text': "Ended up at Erawan after our intended place did not pan out. Hadn't been in a long time but it was still just as I remembered it. \n\nOrdered a couple...",
#    'rating': 5,
#    'time_created': '2023-01-10 04:03:17',
#    'user': {'id': 'q9Tbr48WBWyXbJkKcit91Q',
#     'profile_url': 'https://www.yelp.com/user_details?userid=q9Tbr48WBWyXbJkKcit91Q',
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/o1ISbv_YU0ciSzKs2CL0ag/o.jpg',
#     'name': 'Billy B.'}},
#   {'id': 'gweC2bCOVLZiz4SYjXf-IQ',
#    'url': 'https://www.yelp.com/biz/erawan-thai-restaurant-syracuse?adjust_creative=H2mBmGHSsANIEiZZaA4ZyA&hrid=gweC2bCOVLZiz4SYjXf-IQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=H2mBmGHSsANIEiZZaA4ZyA',
#    'text': 'Great local Thai place!! It has been known to be one of the best in Syracuse. Conveniently located with plenty of seating.  So many food options for...',
#    'rating': 4,
#    'time_created': '2023-01-31 12:53:02',
#    'user': {'id': 'EuBGcX3Wo4pFXA3Om54ijQ',
#     'profile_url': 'https://www.yelp.com/user_details?userid=EuBGcX3Wo4pFXA3Om54ijQ',
#     'image_url': 'https://s3-media4.fl.yelpcdn.com/photo/zSbRh5aQjkkJZbbDgivT5w/o.jpg',
#     'name': 'Marc G.'}},
#   {'id': 'U-mDDChthRKMG-9IjCafkg',
#    'url': 'https://www.yelp.com/biz/erawan-thai-restaurant-syracuse?adjust_creative=H2mBmGHSsANIEiZZaA4ZyA&hrid=U-mDDChthRKMG-9IjCafkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=H2mBmGHSsANIEiZZaA4ZyA',
#    'text': 'Great Thai! The lunch prices are fantastic. Super friendly staff and delicious food choices. \nThai iced tea is always a special treat too!',
#    'rating': 5,
#    'time_created': '2023-02-19 09:03:24',
#    'user': {'id': 'r_mg0y5LTT56ismrk84q_g',
#     'profile_url': 'https://www.yelp.com/user_details?userid=r_mg0y5LTT56ismrk84q_g',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/t9uesKYHERePNNbR6pGGIQ/o.jpg',
#     'name': 'Rich R.'}}],
#  'total': 143,
#  'possible_languages': ['en']}

# %%
get_sentiment("I don't give one star reviews lightly, nor do I ever throw out food, but Erawan has forced me to do both.  I ordered pad Thai from here.")
# Out:
# 'negative'

# %%
def yelp_search(term, location):
    querystring = { 'term' : term, 'location' : location }
    header = { 'Authorization' : f'Bearer {yelp_api_key}'}
    search_url = "https://api.yelp.com/v3/businesses/search"
    response = requests.get(search_url, params = querystring, headers=header)
    return response.json()

def yelp_details(id):
    header = { 'Authorization' : f'Bearer {yelp_api_key}'}
    details_url = f"https://api.yelp.com/v3/businesses/{id}"
    response = requests.get(details_url, headers = header)
    return response.json()
        
def yelp_reviews(id):
    header = { 'Authorization' : f'Bearer {yelp_api_key}'}
    details_url = f"https://api.yelp.com/v3/businesses/{id}/reviews"
    response = requests.get(details_url, headers = header)
    return response.json()

# %%
# main program 
@interact_manual(cuisine="", location="")
def main(cuisine="",location=""):
    results = yelp_search(cuisine, location)

    display(HTML(f"<h1>{cuisine.title()} in {location}"))
    for business in results['businesses'][:10]:
        display(HTML(f"<h2>Review Analysis for <em>{business['name']}</em></h2>"))
        display(Image(business['image_url'], width=200))
        reviews = yelp_reviews(business['id'])
        for review in reviews['reviews']:
            sentiment = get_sentiment(review['text'])
            print(f"=> {review['user']['name']} Rating: {review['rating']} Sentiment: {sentiment}")
# Out:
# interactive(children=(Text(value='', description='cuisine'), Text(value='', description='location'), Button(de…
