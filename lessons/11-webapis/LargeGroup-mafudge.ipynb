# %% [markdown]
# # Code Samples From Large Group
#
# Place your notes and code samples from large group here.

# %%
googlekey = 'AIzaSyBQW2Urw2sIAWxK81wqSgfhBslTW-cgR1k'

# %%
results = {'probability': {
   'neg': 0.520097595188211,
   'neutral': 0.3886824782142297,
   'pos': 0.479902404811789
    },
  'label': 'neg'
}

# %%
results['label']
# Out:
# 'neg'

# %%
z = { 'a' : [3,4,5], 'b' : {'s' : "wer" } }

# %%
z['a'][2] # 5
# Out:
# 5

# %%
z['b']['s'] # wer
# Out:
# 'wer'

# %%
z['c'] # KeyError
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_205/144595941.py in <module>
# ----> 1 z['c'] # KeyError
#
# KeyError: 'c'

# %%
z['b'][4] # Index Error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_205/3700384682.py in <module>
# ----> 1 z['b'][4] # Index Error
#
# KeyError: 4

# %%
# %%pybot
#
# what are some good api's for recipes?

# %%
#AI-Generated Output (Tokens: prompt=17, output=78)
'''
1. Food2Fork API
2. Edamam API
3. Spoonacular API
4. Yummly API
5. Nutritionix API
6. Recipe Puppy API
7. Recipe Search API by Yummly
8. Edamam Nutrition Analysis API
9. Recipe - Food - Nutrition API by Spoonacular
10. BigOven Recipe AP
'''
'''
I
'''

# %%
import requests
params = { "i" : "onions,garlic", "q" : "omelet"}
url = "http://www.recipepuppy.com/api/"
response = requests.get(url, params=params)
response.raise_for_status()
results = response.json()


results
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipykernel_205/4173277633.py in <module>
#       3 url = "http://www.recipepuppy.com/api/"
#       4 response = requests.get(url, params=params)
# ----> 5 response.raise_for_status()
#       6 results = response.json()
#       7
#
# /opt/conda/lib/python3.9/site-packages/requests/models.py in raise_for_status(self)
#     951
#     952         if http_error_msg:
# --> 953             raise HTTPError(http_error_msg, response=self)
#     954
#     955     def close(self):
#
# HTTPError: 500 Server Error: Internal Server Error for url: http://www.recipepuppy.com/api/?i=onions%2Cgarlic&q=omelet

# %%
eapikey='8fc552ba55d5ca73e97548cba30e876d'
url = "https://api.edamam.com/api/food-database/v2/nutrients"

# %%
# %%pybot
#
# Can you turn this curl command into python requests?
#
# curl -X GET --header "Accept: application/json" "https://api.edamam.com/api/food-database/v2/parser?app_id=9f81128b&app_key=8fc552ba55d5ca73e97548cba30e876d&ingr=cheese&nutrition-type=cooking"

# %%
# %%pybot
#
# please convert this query string into a python dict
#
# app_id=9f81128b&app_key=8fc552ba55d5ca73e97548cba30e876d&ingr=cheese&nutrition-type=cooking

# %%
#AI-Generated Output (Tokens: prompt=59, output=56)
'''
{
    "app_id": "9f81128b",
    "app_key": "8fc552ba55d5ca73e97548cba30e876d",
    "ingr": "cheese",
    "nutrition-type": "cooking"
}
'''

# %%
#AI-Generated Output (Tokens: prompt=89, output=89)
import requests
params = {
    "app_id": "9f81128b",
    "app_key": "8fc552ba55d5ca73e97548cba30e876d",
    "ingr": "apple cider vinegar",
    "nutrition-type": "cooking"
}
url = "https://api.edamam.com/api/food-database/v2/parser"
headers = {"Accept": "application/json"}
response = requests.get(url, headers=headers, params=params)
results = response.json()


results
# Out:
# {'text': 'apple cider vinegar',
#  'parsed': [{'food': {'foodId': 'food_ar8m7esapmfvf8bnhfzdlabndh6v',
#     'label': 'Apple Cider Vinegar',
#     'knownAs': 'apple cider vinegar',
#     'nutrients': {'ENERC_KCAL': 21.0,
#      'PROCNT': 0.0,
#      'FAT': 0.0,
#      'CHOCDF': 0.93,
#      'FIBTG': 0.0},
#     'category': 'Generic foods',
#     'categoryLabel': 'food',
#     'image': 'https://www.edamam.com/food-img/c7d/c7dbd1846c5d08e9739930d70a404d50.jpg'}}],
#  'hints': [{'food': {'foodId': 'food_ar8m7esapmfvf8bnhfzdlabndh6v',
#     'label': 'Apple Cider Vinegar',
#     'knownAs': 'apple cider vinegar',
#     'nutrients': {'ENERC_KCAL': 21.0,
#      'PROCNT': 0.0,
#      'FAT': 0.0,
#      'CHOCDF': 0.93,
#      'FIBTG': 0.0},
#     'category': 'Generic foods',
#     'categoryLabel': 'food',
#     'image': 'https://www.edamam.com/food-img/c7d/c7dbd1846c5d08e9739930d70a404d50.jpg'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit',
# ...

# %%
# !pip install edamam-api

# %%
# UNFORTUNATELY THISDID NOT WORK

import Edamam

Edamam.appID = params['app_id']
Edamam.appKey = params['app_key']

test = Edamam.RecipeSearch({'q':'scrambled egg and salmon', 'to':10}).getResults()

print("Results:")
for result in test:
    print(result.label + "\t" + result.url)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_604/2859288152.py in <module>
# ----> 1 import Edamam
#       2
#       3 Edamam.appID = params['app_id']
#       4 Edamam.appKey = params['app_key']
#       5
#
# ModuleNotFoundError: No module named 'Edamam'

# %%
import edamam_api

# %%
edamam_api?
